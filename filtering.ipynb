# %% [markdown]
# 1. Make the filtering for the general 5 standard deviation filtering
#
#     Ca:
#     Cb:
#     Cy:
#     Cg:
#     Ce:
#
#
# special rules:
#
# 2. Ca should not be lower than 45 if it has anyother carbon types detected
#
# 3. Cb should not be more than 50 if their is any C-g or Cy > 30
#
# 4. Cb should not be less than 25 if Cy or Cg detected or if Ca is greater than 59
