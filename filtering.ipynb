# %% [markdown]
# 1. Make the filtering for the general 5 standard deviation filtering
#
#     Ca max: 76.647
#     Ca min: 38.925
#
#     Cb max: 78.143
#     cb min: 10.237
#
#     Cd max: 55.558
#     Cd min: 5.22
#
#     Cg max: 41.985
#     Cg min: 13.731
#
#     cg1 max:36.25
#     cg1 min:19.26
#
#     cg2 max:24.049
#     cg2 min:10.989
#
#     Ce max: 37.606
#     Ce min: 46.186
#
#
# special rules:
#
# 2. Ca should not be lower than 40.779 if it has anyother carbon types detected
#
# 3. Cb should not be more than 66.213 if their is any C-g or Cy > 30
#
# 4. Cb should not be less than 19.882 if Cy or Cg detected or if Ca is greater than 62.76
